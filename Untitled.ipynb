# %% [markdown]
# ### 3. Data preparation for machine learning
# Before you train the model for prediction, you need to perform data [cleaning](https://www.dataquest.io/blog/machine-learning-preparing-data/) and [preprocessing](https://towardsdatascience.com/data-preprocessing-concepts-fa946d11c825). This is a very important step; your model will not perform well without these steps.
#
# ![48f91a8a-d9c4-4853-ab32-ccb9f143a238.png](data:image/png;base64,...)

# %%
import pandas as pd, numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the data
SHARE_PRICES = pd.read_csv("lstmmodel/SharePrice.csv")
SHARE_PRICES.head()
# Out:
#          Date  HFC    UNIL  MLC  ALW  PBC  GGBL  CMLT  SWL   FML    SCB  GCB
# 0  1990-11-12  NaN  1800.0  NaN  NaN  NaN  83.0   NaN  NaN  25.0  200.0  NaN
# 1  1990-11-20  NaN  1600.0  NaN  NaN  NaN  85.0   NaN  NaN  25.0  200.0  NaN
# 2  1990-11-23  NaN  1650.0  NaN  NaN  NaN  85.0   NaN  NaN  25.0  200.0  NaN
# 3  1990-11-27  NaN  1655.0  NaN  NaN  NaN  86.0   NaN  NaN  25.0  255.0  NaN
# 4  1990-11-30  NaN  1655.0  NaN  NaN  NaN  84.0   NaN  NaN  25.0  255.0  NaN

# %%
# convert Date column to datetime format and set it as the index
SHARE_PRICES['Date'] = pd.to_datetime(SHARE_PRICES['Date'])
SHARE_PRICES = SHARE_PRICES.set_index('Date')

# print the timeseries
SHARE_PRICES.head()
# Out:
#             HFC    UNIL  MLC  ALW  PBC  GGBL  CMLT  SWL   FML    SCB  GCB
# Date
# 1990-11-12  NaN  1800.0  NaN  NaN  NaN  83.0   NaN  NaN  25.0  200.0  NaN
# 1990-11-20  NaN  1600.0  NaN  NaN  NaN  85.0   NaN  NaN  25.0  200.0  NaN
# 1990-11-23  NaN  1650.0  NaN  NaN  NaN  85.0   NaN  NaN  25.0  200.0  NaN
# 1990-11-27  NaN  1655.0  NaN  NaN  NaN  86.0   NaN  NaN  25.0  255.0  NaN
# 1990-11-30  NaN  1655.0  NaN  NaN  NaN  84.0   NaN  NaN  25.0  255.0  NaN

# %% [markdown]
# Missing value imputation using the Kalman filter method provided by the` imputeTS` package. It checks if there are any missing values in the SHARE_PRICES dataframe and, if there are, it applies the na_kalman function to impute those missing values. The model argument is set to `"auto.arima"`, which means that the function will automatically select the best ARIMA model to use for imputation. The smooth argument is set to TRUE, which means that the imputed values will be smoothed using the Kalman filter. If there are no missing values in the dataframe, the function simply returns the original SHARE_PRICES dataframe without performing any imputation.

# %%
# Perform backward fill
SHARE_PRICES = SHARE_PRICES.fillna(method='bfill')
SHARE_PRICES.head()
# Out:
#               HFC    UNIL   MLC     ALW    PBC  GGBL   CMLT    SWL   FML  \
# Date
# 1990-11-12  102.0  1800.0  52.0  1410.0  515.0  83.0  400.0  260.0  25.0
# 1990-11-20  102.0  1600.0  52.0  1410.0  515.0  85.0  400.0  260.0  25.0
# 1990-11-23  102.0  1650.0  52.0  1410.0  515.0  85.0  400.0  260.0  25.0
# 1990-11-27  102.0  1655.0  52.0  1410.0  515.0  86.0  400.0  260.0  25.0
# 1990-11-30  102.0  1655.0  52.0  1410.0  515.0  84.0  400.0  260.0  25.0
#
#               SCB    GCB
# Date
# 1990-11-12  200.0  539.0
# 1990-11-20  200.0  539.0
# 1990-11-23  200.0  539.0
# 1990-11-27  255.0  539.0
# 1990-11-30  255.0  539.0

# %%
# Divide each row of the data frame by 1000, 
SHARE_PRICES=SHARE_PRICES.iloc[0:2784,0:11 ] / 10000
SHARE_PRICES.head()
# Out:
#                HFC    UNIL     MLC    ALW     PBC    GGBL  CMLT    SWL  \
# Date
# 1990-11-12  0.0102  0.1800  0.0052  0.141  0.0515  0.0083  0.04  0.026
# 1990-11-20  0.0102  0.1600  0.0052  0.141  0.0515  0.0085  0.04  0.026
# 1990-11-23  0.0102  0.1650  0.0052  0.141  0.0515  0.0085  0.04  0.026
# 1990-11-27  0.0102  0.1655  0.0052  0.141  0.0515  0.0086  0.04  0.026
# 1990-11-30  0.0102  0.1655  0.0052  0.141  0.0515  0.0084  0.04  0.026
#
#                FML     SCB     GCB
# Date
# 1990-11-12  0.0025  0.0200  0.0539
# 1990-11-20  0.0025  0.0200  0.0539
# 1990-11-23  0.0025  0.0200  0.0539
# 1990-11-27  0.0025  0.0255  0.0539
# 1990-11-30  0.0025  0.0255  0.0539

# %%
SHARE_PRICES.columns
# Out:
# Index(['HFC', 'UNIL', 'MLC', 'ALW', 'PBC', 'GGBL', 'CMLT', 'SWL', 'FML', 'SCB',
#        'GCB'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# resample data based on monthly frequency and compute the mean of each month
monthly_data = SHARE_PRICES.resample('M').mean()

# plot the data
plt.plot(monthly_data.index, monthly_data['GCB'])
plt.xlabel('Month')
plt.ylabel('Share Price')
plt.title('GCB Share Price by Month')
plt.show()

# %%
# plot the data
plt.plot(monthly_data.index, monthly_data['HFC'])
plt.xlabel('Month')
plt.ylabel('Share Price')
plt.title('GCB Share Price by Month')
plt.show()

# %%
# plot the data
plt.plot(monthly_data.index, monthly_data['GGBL'])
plt.xlabel('Month')
plt.ylabel('Share Price')
plt.title('GCB Share Price by Month')
plt.show()

# %%
import matplotlib.pyplot as plt

# Resample the data by month
ts_monthly = SHARE_PRICES.resample('M').mean()

# Plot all variables on one plot
plt.figure(figsize=(12, 6))
plt.plot(ts_monthly.index, ts_monthly['HFC'], label='HFC')
plt.plot(ts_monthly.index, ts_monthly['UNIL'], label='UNIL')
plt.plot(ts_monthly.index, ts_monthly['MLC'], label='MLC')
plt.plot(ts_monthly.index, ts_monthly['ALW'], label='ALW')
plt.plot(ts_monthly.index, ts_monthly['PBC'], label='PBC')
plt.plot(ts_monthly.index, ts_monthly['GGBL'], label='GGBL')
plt.plot(ts_monthly.index, ts_monthly['CMLT'], label='CMLT')
plt.plot(ts_monthly.index, ts_monthly['SWL'], label='SWL')
plt.plot(ts_monthly.index, ts_monthly['FML'], label='FML')
plt.plot(ts_monthly.index, ts_monthly['SCB'], label='SCB')
plt.plot(ts_monthly.index, ts_monthly['GCB'], label='GCB')
plt.legend()
plt.xlabel('Month')
plt.ylabel('Price')
plt.title('Share Prices by Month')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Decompose the time series
decompositions = {}
for col in SHARE_PRICES.columns:
    decomposition = seasonal_decompose(SHARE_PRICES[col], model='additive', period=365)
    decompositions[col] = decomposition

# Plot the results
for col, decomposition in decompositions.items():
    decomposition.plot()

# %%
SHARE_PRICES = SHARE_PRICES.diff().dropna()

# %%
from statsmodels.tsa.stattools import adfuller

# loop through each column in the dataframe
for col in SHARE_PRICES.columns:
    # perform ADF test on the column
    result = adfuller(SHARE_PRICES[col])
    
    # extract test statistics and p-value
    test_statistic = result[0]
    p_value = result[1]
    
    # print the results
    print('Column:', col)
    print('Test Statistic:', test_statistic)
    print('p-value:', p_value)
    print('Is stationary:', p_value < 0.05)
    print('\n')
# Out:
# Column: HFC
# Test Statistic: -7.2923111821399775
# p-value: 1.406785150809313e-10
# Is stationary: True
#
#
# Column: UNIL
# Test Statistic: -7.856768152563264
# p-value: 5.416580962182565e-12
# Is stationary: True
#
#
# Column: MLC
# Test Statistic: -8.110842343970223
# p-value: 1.227098140018063e-12
# Is stationary: True
#
#
# Column: ALW
# Test Statistic: -14.865722453598481
# p-value: 1.692682245393472e-27
# Is stationary: True
#
#
# Column: PBC
# Test Statistic: -7.3380552578208995
# p-value: 1.0833677724407385e-10
# Is stationary: True
#
#
# Column: GGBL
# Test Statistic: -10.44670317170368
# p-value: 1.4737588075342876e-18
# Is stationary: True
#
#
# Column: CMLT
# Test Statistic: -5.401379917993428
# p-value: 3.3646723714191e-06
# Is stationary: True
#
#
# Column: SWL
# Test Statistic: -23.97332852158381
# p-value: 0.0
# Is stationary: True
#
#
# Column: FML
# Test Statistic: -6.823711879855573
# p-value: 1.972150441012054e-09
# Is stationary: True
#
#
# Column: SCB
# ...

# %%
SHARE_PRICES.plot(figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# we are going to use a hybrid model that combines three different techniques: wavelet transform (WT), long short-term memory (LSTM), and an adaptive genetic algorithm (AGA) and compare it to ARIMA, SARIMA, and Prophet
#
# First, we will use the wavelet transform (WT) to decompose the time series into multiple scales or sub-series. The purpose of this is to capture different levels of variability and trends in the time series. We can use the pywt package to perform the wavelet transform.
#
# Next, we will use the long short-term memory (LSTM) neural network to model the sub-series at each scale. LSTM is a type of recurrent neural network that is well-suited for time series forecasting because it can capture long-term dependencies and patterns in the data. We can use the Keras API in TensorFlow to implement the LSTM.
#
# Finally, we will use an adaptive genetic algorithm (AGA) to optimize the hyperparameters of the LSTM model. The AGA is a type of evolutionary algorithm that can search for the best set of hyperparameters to maximize the forecasting accuracy. We can use the DEAP package to implement the AGA.
#
# Here are the general steps to build the hybrid model:
#
# Perform wavelet transform on the time series to decompose it into multiple scales.
# For each scale, prepare the data for LSTM modeling (e.g., split into training and test sets, normalize the data).
# Train an LSTM model on each scale using the training data and validate the model using the test data.
# Use an AGA to optimize the hyperparameters of each LSTM model.
# Combine the predictions from all LSTM models to obtain the final forecast.

# %%
import pywt # for wavelet transform

def wavelet_decomposition(series, wavelet='db4', level=4):
    # Perform wavelet decomposition
    coeffs = pywt.wavedec(series, wavelet, level=level)
    # Reconstruct the approximations and details
    cA = [coeffs[0]]
    cD = []
    for i in range(level):
        cD.append(coeffs[i+1])
        cA.append(pywt.waverec([cA[i], coeffs[i+1]], wavelet))
    return cA[1:], cD[::-1]

# %%
# Define the number of sub-series at each level
num_subseries = 2

# Create a list to hold the sub-series at each level
subseries_list = []

# Loop through the decomposition at each level
for i in range(level):
    # Get the sub-series at this level
    cA_i, cD_i = cA[i], cD[i]
    
    # Split the sub-series into smaller sub-series
    cA_subseries = np.array_split(cA_i, num_subseries)
    cD_subseries = np.array_split(cD_i, num_subseries)
    
    # Add the smaller sub-series to the list
    subseries_list.append(cA_subseries + cD_subseries)

# %%
def plot_wavelet_coeffs(cA, cD, labels):
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.stackplot(range(len(cA[-1])), cA[-1], labels=labels, alpha=0.7)
    ax.set_xlabel('Time')
    ax.set_ylabel('Value')
    ax.legend(loc='upper left')
    plt.show()

# %%
cA, cD = wavelet_decomposition(SHARE_PRICES['HFC'])
plot_wavelet_coeffs(cA, cD, ['cD4', 'cD3', 'cD2', 'cD1', 'cA4'])

# %% [markdown]
# We can create a function that takes in the wavelet decomposed data and applies the LSTM model to each of the sub-series.

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

# %%
def create_lstm_model(n_steps, n_features):
    # define the LSTM model
    model = Sequential()
    model.add(LSTM(50, input_shape=(n_steps, n_features)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model

def apply_lstm_to_subseries(subseries, n_steps, n_features):
    # reshape the data into a format that can be fed into the LSTM
    X = []
    y = []
    for i in range(n_steps, len(subseries)):
        X.append(subseries[i-n_steps:i])
        y.append(subseries[i])
    X, y = np.array(X), np.array(y)
    X = np.reshape(X, (X.shape[0], X.shape[1], n_features))

# %%
X, y = [], []
for subseries in subseries_list:
    X_sub, y_sub = apply_lstm_to_subseries(subseries, n_steps, n_features)
    X.append(X_sub)
    y.append(y_sub)
X, y = np.vstack(X), np.hstack(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12080\1040306189.py in <module>
#       4     X.append(X_sub)
#       5     y.append(y_sub)
# ----> 6 X, y = np.vstack(X), np.hstack(y)
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     280     if not isinstance(arrs, list):
#     281         arrs = [arrs]
# --> 282     return _nx.concatenate(arrs, 0)
#     283
#     284
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %%
    # create and fit the LSTM model
    model = create_lstm_model(n_steps, n_features)
    model.fit(X, y, epochs=50, verbose=0)
    model
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12080\3899835478.py in <module>
#       1 # create and fit the LSTM model
#       2 model = create_lstm_model(n_steps, n_features)
# ----> 3 model.fit(X, y, epochs=50, verbose=0)
#       4 model
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     257         inputs = pack_x_y_sample_weight(x, y, sample_weights)
#     258
# ...

# %%
    # use the LSTM model to make predictions on the data
    predictions = []
    for i in range(n_steps, len(subseries)):
        X_test = subseries[i-n_steps:i]
        X_test = np.reshape(X_test, (1, n_steps, n_features))
        y_pred = model.predict(X_test)[0][0]
        predictions.append(y_pred)
    
    return predictions

# %% [markdown]
# We can then use this function to apply the LSTM model to each of the sub-series at each scale.

# %%
n_steps = 3
n_features = 1

for i in range(len(cD)):
    subseries = cD[i]
    predictions = apply_lstm_to_subseries(subseries, n_steps, n_features)
    # do something with the predictions
# Out:
# ...
# 1/1 [==============================] - 0s 47ms/step
# ...
# ...
# 1/1 [==============================] - 0s 46ms/step

# %%
def inverse_wavelet_transform(cA, cD, wavelet='db4'):
    # Reconstruct the time series using inverse wavelet transform
    coeffs = [cA[-1]]
    for i in range(len(cD)):
        coeffs.append(cD[len(cD)-i-1])
    return pywt.waverec(coeffs, wavelet)

def predict_and_combine(cA, cD, model):
    # Predict each sub-series using the LSTM model
    predictions = []
    for i in range(len(cA)):
        X, y = create_dataset(cA[i], cD[i], n_steps)
        X = np.reshape(X, (X.shape[0], X.shape[1], 1))
        yhat = model.predict(X)
        predictions.append(yhat)
    # Combine the predictions back to obtain the final prediction
    combined = np.zeros((len(predictions[0]),))
    for i in range(len(predictions)):
        combined += inverse_wavelet_transform(cA[:i]+[predictions[i]]+cD[len(cD)-i-1:], wavelet)
    return combined

# %%
final_prediction = predict_and_combine(cA, cD, )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12080\2541359037.py in <module>
# ----> 1 final_prediction = predict_and_combine(cA, cD, Sequential())
#
# ~\AppData\Local\Temp\ipykernel_12080\1323615112.py in predict_and_combine(cA, cD, model)
#      10     predictions = []
#      11     for i in range(len(cA)):
# ---> 12         X, y = create_dataset(cA[i], cD[i], n_steps)
#      13         X = np.reshape(X, (X.shape[0], X.shape[1], 1))
#      14         yhat = model.predict(X)
#
# NameError: name 'create_dataset' is not defined
